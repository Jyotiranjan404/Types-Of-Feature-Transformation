# %% [markdown]
# # ALL type of Scaling techniques

# %% [markdown]
# # TECHNIQUES are:

# %% [markdown]
# 1. Normalization
# 2. Standardization
# 3. Robust Scaler

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Jyotiranjan padhi\Desktop\data folder\KNN.csv")
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# 0          0.10280           0.06981         0.03987      0.03700
# 1          0.09688           0.11470         0.06387      0.02642
# 2          0.10770           0.07804         0.03046      0.02480
# 3          0.11640           0.11360         0.04635      0.04796
# 4          0.07963           0.06934         0.03393      0.02657
#
#    symmetry_mean  dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
import seaborn as sns
sns.countplot(df['diagnosis'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
del df['id']

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         B        12.32         12.39           78.85      464.1
# 1         B        10.60         18.95           69.28      346.4
# 2         B        11.04         16.83           70.92      373.2
# 3         B        11.28         13.39           73.00      384.8
# 4         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# 0          0.10280           0.06981         0.03987      0.03700
# 1          0.09688           0.11470         0.06387      0.02642
# 2          0.10770           0.07804         0.03046      0.02480
# 3          0.11640           0.11360         0.04635      0.04796
# 4          0.07963           0.06934         0.03393      0.02657
#
#    symmetry_mean  dimension_mean  radius_se  texture_se  perimeter_se  \
# 0         0.1959         0.05955     0.2360      0.6656         1.670
# ...

# %%
df.isnull().sum()
# Out:
# diagnosis            0
# radius_mean          0
# texture_mean         0
# perimeter_mean       0
# area_mean            0
# smoothness_mean      0
# compactness_mean     0
# concavity_mean       0
# points_mean          0
# symmetry_mean        0
# dimension_mean       0
# radius_se            0
# texture_se           0
# perimeter_se         0
# area_se              0
# smoothness_se        0
# compactness_se       0
# concavity_se         0
# points_se            0
# symmetry_se          0
# dimension_se         0
# radius_worst         0
# texture_worst        0
# perimeter_worst      0
# area_worst           0
# smoothness_worst     0
# compactness_worst    0
# concavity_worst      0
# points_worst         0
# symmetry_worst       0
# dimension_worst      0
# dtype: int64

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# count       569.000000        569.000000      569.000000   569.000000
# mean          0.096360          0.104341        0.088799     0.048919
# std           0.014064          0.052813        0.079720     0.038803
# min           0.052630          0.019380        0.000000     0.000000
# ...

# %%
df.corr()
# Out:
#                    radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean           1.000000      0.323782        0.997855   0.987357
# texture_mean          0.323782      1.000000        0.329533   0.321086
# perimeter_mean        0.997855      0.329533        1.000000   0.986507
# area_mean             0.987357      0.321086        0.986507   1.000000
# smoothness_mean       0.170581     -0.023389        0.207278   0.177028
# compactness_mean      0.506124      0.236702        0.556936   0.498502
# concavity_mean        0.676764      0.302418        0.716136   0.685983
# points_mean           0.822529      0.293464        0.850977   0.823269
# symmetry_mean         0.147741      0.071401        0.183027   0.151293
# dimension_mean       -0.311631     -0.076437       -0.261477  -0.283110
# radius_se             0.679090      0.275869        0.691765   0.732562
# texture_se           -0.097317      0.386358       -0.086761  -0.066280
# ...

# %%
X=df.iloc[:,1:]
y=df.iloc[:,:1]

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        12.32         12.39           78.85      464.1          0.10280
# 1        10.60         18.95           69.28      346.4          0.09688
# 2        11.04         16.83           70.92      373.2          0.10770
# 3        11.28         13.39           73.00      384.8          0.11640
# 4        15.19         13.21           97.65      711.8          0.07963
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0           0.06981         0.03987      0.03700         0.1959
# 1           0.11470         0.06387      0.02642         0.1922
# 2           0.07804         0.03046      0.02480         0.1714
# 3           0.11360         0.04635      0.04796         0.1771
# 4           0.06934         0.03393      0.02657         0.1721
#
#    dimension_mean  radius_se  texture_se  perimeter_se  area_se  \
# 0         0.05955     0.2360      0.6656         1.670    17.43
# ...

# %%
y.head()
# Out:
#   diagnosis
# 0         B
# 1         B
# 2         B
# 3         B
# 4         B

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (455, 30)
# (455, 1)
# (114, 30)
# (114, 1)

# %%
X_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 567        14.53         13.98           93.86      644.2          0.10990
# 295        24.63         21.60          165.50     1841.0          0.10300
# 91         12.47         17.31           80.45      480.1          0.08928
# 1          10.60         18.95           69.28      346.4          0.09688
# 94         14.22         23.12           94.37      609.9          0.10750
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 567           0.09242         0.06895      0.06495         0.1650
# 295           0.21060         0.23100      0.14710         0.1991
# 91            0.07630         0.03609      0.02369         0.1526
# 1             0.11470         0.06387      0.02642         0.1922
# 94            0.24130         0.19810      0.06618         0.2384
#
#      dimension_mean  radius_se  texture_se  perimeter_se  area_se  \
# ...

# %%
y_train.head()
# Out:
#     diagnosis
# 567         B
# 295         M
# 91          B
# 1           B
# 94          M

# %%
X_test.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 172        13.71         20.83           90.20      577.9          0.11890
# 553        11.75         17.56           75.89      422.9          0.10730
# 374        12.62         17.15           80.62      492.9          0.08583
# 370        12.54         16.32           81.25      476.3          0.11580
# 419        11.80         16.58           78.99      432.0          0.10910
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 172           0.16450         0.09366      0.05985         0.2196
# 553           0.09713         0.05282      0.04440         0.1598
# 374           0.05430         0.02966      0.02272         0.1799
# 370           0.10850         0.05928      0.03279         0.1943
# 419           0.17000         0.16590      0.07415         0.2678
#
#      dimension_mean  radius_se  texture_se  perimeter_se  area_se  \
# ...

# %%
y_test.head()
# Out:
#     diagnosis
# 172         M
# 553         B
# 374         B
# 370         B
# 419         M

# %% [markdown]
# # Standardization

# %%
# Now i want to scale down my data
from sklearn.preprocessing import StandardScaler
scaler_data=StandardScaler()
scaler_data1=scaler_data.fit_transform(X_train)
scaler_data2=scaler_data.transform(X_test)

# %%
scaler_data1
# Out:
# array([[ 0.12346981, -1.23108472,  0.08779294, ..., -0.10602528,
#         -0.45874065, -0.31288831],
#        [ 2.95394477,  0.53355538,  3.00383508, ...,  2.0187369 ,
#          0.43898535,  0.68293483],
#        [-0.45383499, -0.4599231 , -0.45804912, ..., -0.13020465,
#          0.2402148 , -0.39261837],
#        ...,
#        [ 1.08190786,  0.16534308,  0.91571445, ...,  0.06927516,
#          3.24947055, -1.22202507],
#        [-0.73688248, -0.26308004, -0.73727928, ..., -0.88898351,
#         -1.10718883, -0.4049257 ],
#        [-0.30530511,  0.584503  , -0.17108517, ...,  1.39158448,
#          2.42832009,  1.24425587]])

# %% [markdown]
# # MinMaxScaler

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=100)

# %%
from sklearn.preprocessing import MinMaxScaler
s=MinMaxScaler()
b=s.fit_transform(X_train)
c=s.transform(X_test)

# %%
b
# Out:
# array([[0.81060792, 0.35475144, 0.84137146, ..., 0.77437134, 0.32663118,
#         0.16430539],
#        [0.26892694, 0.52553263, 0.25736236, ..., 0.20685498, 0.17327025,
#         0.08421881],
#        [0.48285168, 0.18058843, 0.47716603, ..., 0.50155012, 0.23477232,
#         0.1584022 ],
#        ...,
#        [0.30866984, 0.20121745, 0.29641485, ..., 0.28301757, 0.11255667,
#         0.07910272],
#        [0.5034591 , 0.37030774, 0.49708351, ..., 0.67998622, 0.29469742,
#         0.19670733],
#        [0.13497866, 0.17822117, 0.13920899, ..., 0.32070272, 0.28681254,
#         0.27167782]])

# %%
c
# Out:
# array([[ 0.10392032,  0.20189381,  0.10726988, ...,  0.22487082,
#          0.18470333,  0.24301456],
#        [ 0.04258869,  0.30064254,  0.0438896 , ...,  0.        ,
#          0.31086142,  0.17132363],
#        [ 0.44212747,  0.40175854,  0.44231043, ...,  0.62452635,
#          0.65010842,  0.20523416],
#        ...,
#        [ 0.20465139,  0.16706121,  0.21475317, ...,  0.20812952,
#          0.22905579,  0.31850977],
#        [ 0.18551592,  0.4808928 ,  0.1892161 , ...,  0.33251808,
#          0.10782574,  0.21172767],
#        [-0.03670085,  0.12580318, -0.02937829, ...,  0.        ,
#          0.2694658 ,  0.2543618 ]])

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=100)

# %%
from sklearn.preprocessing import RobustScaler
a=RobustScaler()
b=a.fit_transform(X_train)
d=a.transform(X_test)

# %%
b
# Out:
# array([[ 2.44948922,  0.26268116,  2.55625504, ...,  1.16341914,
#          0.59852941,  0.02310469],
#        [-0.05675369,  1.17753623, -0.09426957, ..., -0.39871047,
#         -0.54558824, -0.56462094],
#        [ 0.93303065, -0.67028986,  0.90330912, ...,  0.41245911,
#         -0.08676471, -0.02021661],
#        ...,
#        [ 0.12712826, -0.55978261,  0.08297014, ..., -0.18906746,
#         -0.99852941, -0.60216606],
#        [ 1.02837684,  0.34601449,  0.9937046 , ...,  0.90361731,
#          0.36029412,  0.26089049],
#        [-0.67650397, -0.68297101, -0.63050847, ..., -0.08533637,
#          0.30147059,  0.811071  ]])

# %%
d
# Out:
# array([[-0.82020431, -0.55615942, -0.77546408, ..., -0.34912056,
#         -0.46029412,  0.60072202],
#        [-1.10397276, -0.02717391, -1.06311542, ..., -0.96809368,
#          0.48088235,  0.0746089 ],
#        [ 0.7446084 ,  0.51449275,  0.74511703, ...,  0.75096003,
#          3.01176471,  0.3234657 ],
#        ...,
#        [-0.35414302, -0.74275362, -0.28765133, ..., -0.3952022 ,
#         -0.12941176,  1.15475331],
#        [-0.44267877,  0.9384058 , -0.40355125, ..., -0.05281373,
#         -1.03382353,  0.37111913],
#        [-1.4708286 , -0.96376812, -1.39564165, ..., -0.96809368,
#          0.17205882,  0.68399519]])
